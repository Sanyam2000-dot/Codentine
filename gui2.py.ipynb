# %%
from tkinter import *
import sqlite3
import tkinter.messagebox
from tkinter  import ttk
import tkinter as tk
from tkcalendar import *
import re
import datetime
conn=sqlite3.connect("upes.db")
def main_screen():
    global root
    root=Tk()
    root.title("Account")
    root.geometry("{0}x{1}+0+0".format(root.winfo_screenwidth(),root.winfo_screenheight()))
    root.config(bg="powder blue")    
    

    # DEFINE THE BUTTON    
    mybutton1=Button(root,text="Login",command=login,font="bold",width="50",height=3,fg="blue",bg="white",
                     activebackground="red")
    mybutton2=Button(root,text="Ragister",command=ragister,font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton3=Button(root,text="About?",command=about,font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton4=Button(root,text="Exit",command=exit,font="bold",width="50",height=3,fg="blue",bg="white")

    # SHOW THE BUTTON
    Label(root,text="CHOOSE LOGIN OR REGISTER",bg="powder blue", width="300", height="2", font=("Calibri", 50,"bold")).pack() 
    Label(text="",bg="powder blue").pack() 
    mybutton1.pack()
    Label(root,text="",width="50",height=2,bg="powder blue").pack()
    mybutton2.pack()
    Label(root,text="",width="50",height=2,bg="powder blue").pack()
    mybutton3.pack()
    Label(root,text="",width="50",height=2,bg="powder blue").pack()
    mybutton4.pack()
    Label(root,text="",width="50",height=2,bg="powder blue").pack()


    root.mainloop()
    
def about():
    # Create a Frame
    about=Toplevel(root)
    about.title("About")
    about.geometry("{0}x{1}+0+0".format(about.winfo_screenwidth(),about.winfo_screenheight()))
    frm=Frame(about)
    frm.pack(padx=50)
    frm1=LabelFrame(frm,width=1350,height=600,font=('arial',20,"bold"),relief='ridge',bg='white',bd=20)
    frm1.pack()
    # Create the space label
    Label(frm1,text="",bg='white').pack()
    # Create the Label of username
    label=Label(frm1,text="This is an application which is used for Enroll the course in College. In this you ",
                font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    Label(frm1,text="",bg='white').pack()
    label=Label(frm1,text="can view the courses and fill the form according to your course which you like to do.",
                font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    Label(frm1,text="",bg='white').pack()
    label=Label(frm1,text="Created By the:- ",
                font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    label=Label(frm1,text="",font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    label=Label(frm1,text="ABHISHEK SHARMA.",
                font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    label=Label(frm1,text="",font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    label=Label(frm1,text="FARHAN KHAN.",
                font=("Calibri", 20,'bold'),bg='white')
    label.pack()
    
def ragister():
    
    global ragister_screen
    ragister_screen=Toplevel(root)
    ragister_screen.grid()
    ragister_screen.title("Ragister")
    ragister_screen.geometry("{0}x{1}+0+0".format(ragister_screen.winfo_screenwidth(),ragister_screen.winfo_screenheight()))
    
    global username
    global password
    global user_name_entry
    global password_entry
    global confirm_password_entry
    username=StringVar()
    password=StringVar()
    confirm_password=StringVar()
    # Create the Label 
    Label(ragister_screen,text="FOR REGISTRATION", bg="blue", width="300", height="3", font=("Calibri", 20,"bold")).pack() 
    Label(ragister_screen,text="").pack()
   
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the Label of username
    username_label=Label(ragister_screen,text="Username",font=("Calibri", 13))
    username_label.pack()
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the text box of username
    user_name_entry=Entry(ragister_screen,width=20,textvariable=username)
    user_name_entry.pack()
    
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the Label of password
    password_label1=Label(ragister_screen,text="Password",font=("Calibri", 13))
    password_label1.pack()
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the text box of password
    password_entry=Entry(ragister_screen,width=20,textvariable=password,show="*")
    password_entry.pack()
    
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the Label of confirm password
    password_label2=Label(ragister_screen,text="Confirm Password",font=("Calibri", 13))
    password_label2.pack()
    # Create the space label
    Label(ragister_screen,text="").pack()
    # Create the text box of confirm password
    confirm_password_entry=Entry(ragister_screen,width=20,textvariable=confirm_password,show="*")
    confirm_password_entry.pack()
    

    # show the ragister button
    Label(ragister_screen,text="").pack()
    Label(ragister_screen,text="").pack()
    Label(ragister_screen,text="").pack()
    button_ragister=Button(ragister_screen,text="Ragister",font="bold",width=15,
                            height=1,fg="blue",bg="white",command=ragister_user).pack()
   
     
    
    
    
   
    
def ragister_user():
    conn.execute("create table if not exists ragister(username varchar(40) primary key, password varchar(30) not null)")
    cursor=conn.execute("select username from ragister")
    z=0
    if user_name_entry.get()=="" and password_entry.get()=="":
        tkinter.messagebox.showinfo("warning","Please fill all information!")
    elif user_name_entry.get()=="":
        tkinter.messagebox.showinfo("warning","Please fill username information!")
    elif password_entry.get()=="":
        tkinter.messagebox.showinfo("warning","Please fill password information!")
    for i in cursor:
        if user_name_entry.get() in i:
            z=1
    if confirm_password_entry.get()!=password_entry.get():
        # Delete the text boxes information
        user_name_entry.delete(0,END)
        password_entry.delete(0,END)
        tkinter.messagebox.showinfo("warning","Password is incorrect")
    elif z==1:
        # Delete the text boxes information
        user_name_entry.delete(0,END)
        password_entry.delete(0,END)
        tkinter.messagebox.showinfo("warning","Username already exists!")
        
    else:
        conn.execute("insert into ragister values(:username,:password)",
                     {
                       'username':user_name_entry.get(),
                       'password':password_entry.get()
                     }
                    )
        c=conn.execute("select * from ragister")
        for i in c:
            print(i[0])
            print(i[1])
        conn.commit()
        tkinter.messagebox.showinfo("Successful!!","Successfully Ragistered.")
        

            
            
def login():
        global login_screen
        login_screen=Toplevel(root)
        login_screen.grid()
        login_screen.title("Ragister")
        login_screen.geometry("{0}x{1}+0+0".format(login_screen.winfo_screenwidth(),login_screen.winfo_screenheight()))
        login_screen.config(bg="powder blue")
        
        # create a frame
        frm=Frame(login_screen,bg="powder blue")
        frm.pack()
        
        
        
        global login_username
        global login_password
        global login_user_name_entry
        global login_password_entry
        login_username=StringVar()
        login_password=StringVar()
        
        # Create the Label
        Label(frm,text="FOR LOGIN",bg="powder blue" ,
              width="300", height="3", font=("Calibri", 50,"bold")).pack() 
        Label(frm,text="",bg='powder blue').pack()
        
        # create a login frame
        logfrm1=LabelFrame(frm,width=1350,height=600,font=('arial',20,"bold"),relief='ridge',bg='cadet blue',bd=20)
        logfrm1.pack()
        
        # Create the space label
        Label(logfrm1,text="",bg='cadet blue').pack()
        # Create the Label of username
        username_label=Label(logfrm1,text="Enter the Username",font=("Calibri", 25,'bold'),bg='cadet blue')
        username_label.pack()
        # Create the space label
        Label(logfrm1,text="",bg='cadet blue').pack()
        # Create the text box of username
        login_user_name_entry=Entry(logfrm1,width=20,textvariable=login_username,bd=10,font=("Calibri", 15))
        login_user_name_entry.pack()

        # Create the space label
        Label(logfrm1,text="",bg='cadet blue').pack()
        # Create the Label of password
        password_label1=Label(logfrm1,text="Enter the Password",font=("Calibri", 25,'bold'),bg='cadet blue')
        password_label1.pack()
        # Create the space label
        Label(logfrm1,text="",bg='cadet blue').pack()
        # Create the text box of password
        login_password_entry=Entry(logfrm1,width=20,textvariable=login_password,show="*",bd=10,font=("Calibri", 15))
        login_password_entry.pack()
        
        
        # show the ragister button
        Label(frm,text="",bg="powder blue").pack()
        Label(frm,text="",bg="powder blue").pack()
        Label(frm,text="",bg="powder blue").pack()
        button_login=Button(frm,text="Login",font="bold",width=15,
                            height=1,command=login_user,bg="white",fg="blue").pack()
        
        
        
def login_user():
    n=conn.execute("select username from ragister")
    s=login_user_name_entry.get()
    p=conn.execute("select password from ragister where username=?",(s,))
    q=0
    a=0
    for i in n:
        if login_user_name_entry.get() in i:
            q=1
    for i in p:
        if login_password_entry.get() in i:
            a=1
    if a==0 and q==0:
        tkinter.messagebox.showinfo("warning","Wrong password and Username!")
    elif a==1 and q==0:
        tkinter.messagebox.showinfo("warning","Wrong Username!")
    elif a==0 and q==1:
        tkinter.messagebox.showinfo("warning","Wrong Password!")
    elif a==1 and q==1:
        get_character()
    else:
        tkinter.messagebox.showinfo("warning","Invalid!")

        
def get_character():
    global get_character_screen
    get_character_screen=Toplevel(login_screen)
    get_character_screen.title("Who")
    get_character_screen.geometry("{0}x{1}+0+0".format(get_character_screen.winfo_screenwidth(),
                                                       get_character_screen.winfo_screenheight()))  
    
    # Create the Label
    Label(get_character_screen,text="Who ?", bg="blue", 
            width="300", height="3", font=("Calibri", 20,"bold")).pack() 
    Label(get_character_screen,text="").pack()
    
    
    # DEFINE THE BUTTON    
    mybutton1=Button(get_character_screen,text="Student",command=student,
                     font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton2=Button(get_character_screen,text="Admin",
                     command=admin,font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton3=Button(get_character_screen,text="Exit",
                     command=exit,font="bold",width="50",height=3,fg="blue",bg="white")
        
    # SHOW THE BUTTON
    Label(get_character_screen,text="").pack() 
    mybutton1.pack()
    Label(get_character_screen,text="",width="50",height=2).pack()
    mybutton2.pack()    
    Label(get_character_screen,text="",width="50",height=2).pack()
    mybutton3.pack()
    
    

def student():
    global student_screen
    student_screen=Toplevel(get_character_screen)
    student_screen.title("Student")
    student_screen.geometry("{0}x{1}+0+0".format(student_screen.winfo_screenwidth(),student_screen.winfo_screenheight()))
    
    
    # Create the Label
    Label(student_screen,text="WELCOME! "+login_user_name_entry.get(), bg="blue", 
            width="300", height="3", font=("Calibri", 20,"bold")).pack() 
    Label(student_screen,text="").pack()
    
    # DEFINE THE BUTTON   
    mybutton1=Button(student_screen,text="View The Courses",command=view_course,
                     font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton2=Button(student_screen,text="Enroll A Course",
                     command=check,font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton3=Button(student_screen,text="Back",
                     command=lambda: back(student_screen),font="bold",width="50",height=3,fg="blue",bg="white")
    mybutton4=Button(student_screen,text="Exit",
                     command=exit,font="bold",width="50",height=3,fg="blue",bg="white")
    
    # SHOW THE BUTTON
    Label(student_screen,text="").pack() 
    mybutton1.pack()
    Label(student_screen,text="",width="50",height=2).pack()
    mybutton2.pack()    
    Label(student_screen,text="",width="50",height=2).pack()
    mybutton3.pack()
    Label(student_screen,text="",width="50",height=2).pack()
    mybutton4.pack()
    
    
def view_course():
    global view_course_screen
    view_course_screen=Toplevel(student_screen)
    view_course_screen.title("Student")
    view_course_screen.geometry("{0}x{1}+0+0".format(view_course_screen.winfo_screenwidth(),
                                                     view_course_screen.winfo_screenheight()))
    
    Label(view_course_screen,text="Courses ", bg="blue", 
            width="300", height="3", font=("Calibri", 20,"bold")).pack() 
    Label(view_course_screen,text="").pack()
    
    
    conn.execute("create table if not exists course(COURSE varchar(20),FEES int,DURATION int,COURSE_ID int primary key)")
    
    cuu=conn.cursor()
    cuu.execute("select count(COURSE) from course") 
    data=cuu.fetchone()[0]
    if data==0:
        l=Label(view_course_screen,text="No Courses is to display.",font=("Calibri", 20,"bold"))
        l.place(x=600,y=300)
    else:
        d=conn.execute("select * from course")
        total=d.fetchall()

        # count the no. of rows
        rows=d.rowcount

        # Create a Frame
        frm=Frame(view_course_screen)
        frm.pack(padx=50)

        # table
        tv=ttk.Treeview(frm,columns=(1,2,3,4),show="headings",height=5)
        tv.pack()

        tv.heading(1,text="COURSE")
        tv.heading(2,text="FEES")
        tv.heading(3,text="DURATION")
        tv.heading(4,text="COURSE-ID")
    
    
        for i in total:
            tv.insert('','end',values=i)
        mybutton=Button(view_course_screen,text="Back",
                         command=lambda: back(view_course_screen),font="bold",width="30",height=2,fg="blue",bg="white").pack()
    
    

def check():
    u=conn.execute("select username from enroll")
    ch=0
    for i in u:
        if i[0]==login_user_name_entry.get():
            ch=1
    if ch==1:
        show_form()
    else:
        enroll_course()
    
def show_form():
    global show_form_screen
    print("Already submitted!")
    cur=conn.execute("select * from enroll where username=?",(login_user_name_entry.get(),))
    show_form_screen=Toplevel(root)
    show_form_screen.title("Form")
    show_form_screen.geometry("{0}x{1}+0+0".format(show_form_screen.winfo_screenwidth(),
                                                     show_form_screen.winfo_screenheight()))
    
    for i in cur:
        label=Label(show_form_screen,text="SUCCESSFUL!  YOU SUBMITTED",font=("Calibri",16))
        label.place(x=70,y=10)

        label=Label(show_form_screen,text="Name: ",font=("Calibri",16))
        label.place(x=50,y=70)
        label=Label(show_form_screen,text=i[0],font=("Calibri",16))
        label.place(x=215,y=70)

        label=Label(show_form_screen,text="Father Name: ",font=("Calibri",16))
        label.place(x=50,y=120)
        label=Label(show_form_screen,text=i[1],font=("Calibri",16))
        label.place(x=215,y=120)

        label=Label(show_form_screen,text="Mother Name: ",font=("Calibri",16))
        label.place(x=50,y=170)
        label=Label(show_form_screen,text=i[2],font=("Calibri",16))
        label.place(x=215,y=170)

        label=Label(show_form_screen,text="Gender: ",font=("Calibri",16))
        label.place(x=50,y=220)
        label=Label(show_form_screen,text=i[3],font=("Calibri",16))
        label.place(x=215,y=220)


        label=Label(show_form_screen,text="Date Of Birth: ",font=("Calibri",16))
        label.place(x=50,y=270)
        label=Label(show_form_screen,text=i[4],font=("Calibri",16))
        label.place(x=215,y=270)

        label=Label(show_form_screen,text="Age: ",font=("Calibri",16))
        label.place(x=50,y=315)
        label=Label(show_form_screen,text=i[5],font=("Calibri",16))
        label.place(x=215,y=315)

        label=Label(show_form_screen,text="Course: ",font=("Calibri",16))
        label.place(x=50,y=360)
        label=Label(show_form_screen,text=i[6],font=("Calibri",16))
        label.place(x=215,y=360)


        label=Label(show_form_screen,text="Course Id: ",font=("Calibri",16))
        label.place(x=50,y=400)
        label=Label(show_form_screen,text=i[7],font=("Calibri",16))
        label.place(x=215,y=400)


        label=Label(show_form_screen,text="State: ",font=("Calibri",16))
        label.place(x=50,y=440)
        label=Label(show_form_screen,text=i[8],font=("Calibri",16))
        label.place(x=215,y=440)

        label=Label(show_form_screen,text="Nationality: ",font=("Calibri",16))
        label.place(x=50,y=490)
        label=Label(show_form_screen,text=i[9],font=("Calibri",16))
        label.place(x=215,y=490)

        label=Label(show_form_screen,text="District: ",font=("Calibri",16))
        label.place(x=50,y=540)
        label=Label(show_form_screen,text=i[10],font=("Calibri",16))
        label.place(x=215,y=540)

        label=Label(show_form_screen,text="Email: ",font=("Calibri",16))
        label.place(x=50,y=590)
        label=Label(show_form_screen,text=i[11],font=("Calibri",16))
        label.place(x=215,y=590)

        label=Label(show_form_screen,text="Address: ",font=("Calibri",16))
        label.place(x=50,y=640)
        label=Label(show_form_screen,text=i[12],font=("Calibri",16))
        label.place(x=215,y=640)

        label=Label(show_form_screen,text="Mobile Number: ",font=("Calibri",16))
        label.place(x=50,y=680)
        label=Label(show_form_screen,text=i[13],font=("Calibri",16))
        label.place(x=215,y=680)


    
def enroll_course():
    global enroll_course_screen
    enroll_course_screen=Toplevel(root)
    enroll_course_screen.title("Enroll")
    enroll_course_screen.geometry("{0}x{1}+0+0".format(enroll_course_screen.winfo_screenwidth(),
                                                     enroll_course_screen.winfo_screenheight()))
    
    
    Label(enroll_course_screen,text="Form", bg="cyan", 
            width="300", height="2", font=("Calibri", 20,"bold")).pack() 
    Label(enroll_course_screen,text="").pack()
    
    
    
    global name_entry
    global father_name_entry
    global mother_name_entry
    global gender
    global ent
    global age_entry
    global course_name_entry
    global course_id_entry
    global email_entry
    global nation
    global state
    global mob_entry
    global district_entry
    global address_entry
    global options


    label=Label(enroll_course_screen,text="Name",font=("Calibri",16))
    label.place(x=225,y=86)
    nament=StringVar()
    name_entry=Entry(enroll_course_screen,width=25,textvariable=nament,font=("Calibri", 11))
    name_entry.place(x=311,y=92)


    label=Label(enroll_course_screen,text="Father Name",font=("Calibri",16))
    label.place(x=565,y=86)
    fatent=StringVar()
    father_name_entry=Entry(enroll_course_screen,width=25,textvariable=fatent,font=("Calibri", 11))
    father_name_entry.place(x=715,y=92)


    label=Label(enroll_course_screen,text="Mother Name",font=("Calibri",16))
    label.place(x=965,y=86)
    motent=StringVar()
    mother_name_entry=Entry(enroll_course_screen,width=25,textvariable=motent,font=("Calibri", 11))
    mother_name_entry.place(x=1115,y=92)


    gender=StringVar()
    gender.set(0)
    label=Label(enroll_course_screen,text="Gender",font=("Calibri",16))
    label.place(x=225,y=166)


    r=Radiobutton(enroll_course_screen,text="Male",variable=gender,value="Male")
    r.place(x=365,y=170)
    r=Radiobutton(enroll_course_screen,text="Female",variable=gender,value="Female")
    r.place(x=485,y=170)


    Label(enroll_course_screen,text="Date of birth",font=("Calibri",16)).place(x=225,y=230)
    ent=DateEntry(enroll_course_screen,year=2000,date_pattern='dd/MM/y', background='green',
                        foreground='white', borderwidth=2, )
    ent.place(x=405,y=236)

    Label(enroll_course_screen,text="Age",font=("Calibri",16)).place(x=225,y=291)
    age=StringVar()
    age_entry=Entry(enroll_course_screen,width=10,textvariable=age,font=("Calibri", 11))
    age_entry.place(x=395,y=295)

    Label(enroll_course_screen,text="(*Please fill course name according \n to given in view course format.)",
          font=("Calibri",10)).place(x=30,y=328)
    Label(enroll_course_screen,text="Course Name",font=("Calibri",16)).place(x=225,y=348)
    course_name=StringVar()
    course_name_entry=Entry(enroll_course_screen,width=20,textvariable=course_name,font=("Calibri", 11))
    course_name_entry.place(x=415,y=350)

    
    Label(enroll_course_screen,text="Course Id",font=("Calibri",16)).place(x=225,y=411)
    course_id=StringVar()
    course_id_entry=Entry(enroll_course_screen,width=20,textvariable=course_id,font=("Calibri", 11))
    course_id_entry.place(x=415,y=411)

    Label(enroll_course_screen,text="Email Id",font=("Calibri",16)).place(x=225,y=479)
    email=StringVar()
    email_entry=Entry(enroll_course_screen,width=20,textvariable=email,font=("Calibri", 11))
    email_entry.place(x=415,y=483)


    nation=StringVar()
    nation.set(0)
    nation_label=Label(enroll_course_screen,text="Nationality",font=("Calibri",16))
    nation_label.place(x=225,y=555)


    n=Radiobutton(enroll_course_screen,text="Indian",variable=nation,value="Indian")
    n.place(x=425,y=560)
    n=Radiobutton(enroll_course_screen,text="Other",variable=nation,value="Other")
    n.place(x=535,y=560)


    Label(enroll_course_screen,text="State",font=("Calibri",16)).place(x=225,y=620)
    options=[ "Andhra Pradesh(AP)", "Arunachal Pradesh(AR)", "Assam(AS)", "Bihar(BR)", "Chhattisgarh(CG)",
              "Goa(GA)", "Gujarat(GJ)", "Haryana(HR)", "Himachal Pradesh(HP)", "Jammu and Kashmir(JK)", 
              "Jharkhand(JH)", "Karnataka(KA)","Kerala(KL)","Madhya Pradesh(MP)","Maharashtra(MH)","Manipur(MN)",
              "Meghalaya(ML)", "Mizoram(MZ)", "Nagaland(NL)", "Odisha(OR)", "Punjab(PB)", "Rajasthan(RJ)","Sikkim(SK)",
              "Tamil Nadu(TN)", "Telangana(TS)", "Tripura(TR)", "Uttar Pradesh(UP)", "Uttarakhand(UK)", "West Bengal(WB)"
             ]
    state=StringVar()
    state.set(None)
    drop=OptionMenu(enroll_course_screen,state,*options)
    drop.place(x=415,y=616)


    district_label=Label(enroll_course_screen,text="District",font=("Calibri",16))
    district_label.place(x=685,y=166)
    district=StringVar()
    district_entry=Entry(enroll_course_screen,width=25,textvariable=district,font=("Calibri", 11))
    district_entry.place(x=795,y=170)

    mob_label=Label(enroll_course_screen,text="Mobile No.",font=("Calibri",16))
    mob_label.place(x=685,y=236)
    mob=StringVar()
    mob_entry=Entry(enroll_course_screen,width=25,textvariable=mob,font=("Calibri", 11))
    mob_entry.place(x=835,y=242)

    address_label=Label(enroll_course_screen,text="Address",font=("Calibri",16))
    address_label.place(x=685,y=306)
    address=StringVar()
    address_entry=Entry(enroll_course_screen,width=75,textvariable=address,font=("Calibri", 13))
    address_entry.place(x=790,y=312,height=69)

    Btn=Button(enroll_course_screen,text="Submit",command=click,width=20,height=3)
    Btn.place(x=715,y=711)

def click():
    print(name_entry.get())
    print(father_name_entry.get())
    print(mother_name_entry.get())
    print(gender.get())
    print(ent.get())
    print(age_entry.get())
    print(course_name_entry.get())
    print(course_id_entry.get())
    print(email_entry.get())
    print(nation.get())
    print(state.get())
    print(district_entry.get())
    print(mob_entry.get())
    print(address_entry.get())
    # check all information fill up or not
    
    # checking the conditions
    c=0
    d=0
    ae=0
    be=0
    cn=0
    ci=0
    ed=0
    na=1
    fna=1
    mna=1
    dna=1
    #check the name,district valid or not
    nmm=re.search("\d",name_entry.get())
    fnmm=re.search("\d",father_name_entry.get())
    mnmm=re.search("\d",mother_name_entry.get())
    dnmm=re.search("\d",district_entry.get())
    if(nmm):
        na=0
    if(fnmm):
        fna=0
    if(mnmm):
        mna=0
    if(dnmm):
        dna=0
    
    for i in options:
        if i==state.get():
            c=1
    # checking the correct mobile number
    m=re.search("^[6-9]\d{9}$",mob_entry.get())
    if m:
        d=1
    # check age lies between 18 to 23 or not
    if (age_entry.get()==""):
            label=Label(enroll_course_screen,text="*Please fill all the information.",font=("Calibri",10),fg="red")
            label.place(x=715,y=690)    
    else:
        ag=int(age_entry.get())

        r=re.findall("^\d{2}",ent.get())
        s=re.findall("/\d{2}/",ent.get())
        t=re.findall("\d{2}",s[0])
        u=re.findall("\d{4}",ent.get())
        if r:

            a=ent.get()
            d=int(r[0])
        if t:
            m=int(t[0])
        if u:
            y=int(u[0])
        if 1998<y<2001 and 1<=m<=12 and 1<=d<=31:
            be=1

        to=datetime.date.today()    
        bt=datetime.date(y,m,d)

        ao=to-bt
        age=ao.days//365
    
    
    
    
        if 18<=ag<=23 and age==ag:
            ae=1
    
    
    # check condition the course name is same or not 
    d=conn.execute("select COURSE from course")
    for i in d:
        if i[0]==course_name_entry.get():
            cn=1
    # check condition the course id is same or not 
    
    d=conn.execute("select COURSE_ID from course where COURSE=?",(course_name_entry.get(),))
    for i in d:
        if i[0]==int(course_id_entry.get()):
            ci=1
    # check email is correct or not
    em=re.findall("\w+\.*\w+@\w+.com",email_entry.get())
    if(em):
        ed=1
    
    # check all information fill up or not
    if (name_entry.get()=="" or father_name_entry.get()=="" or mother_name_entry.get()=="" or gender.get()=="0" 
    or ent.get()=="" or age_entry.get()=="" or course_name_entry.get()=="" or course_id_entry.get()=="" 
    or email_entry.get()=="" or nation.get()=="0" or c==0 or district_entry.get()=="" or mob_entry.get()==""
    or address_entry.get()==""):
            label=Label(enroll_course_screen,text="*Please fill all the information.",font=("Calibri",10),fg="red")
            label.place(x=715,y=690)
    
    
    elif na==0:
        label=Label(enroll_course_screen,text="*Please fill correct name.",font=("Calibri",10),fg="red")
        label.place(x=290,y=72)
    elif fna==0:
        label=Label(enroll_course_screen,text="*Please fill correct father name.",font=("Calibri",10),fg="red")
        label.place(x=705,y=72)
    elif mna==0:
        label=Label(enroll_course_screen,text="*Please fill correct mother name.",font=("Calibri",10),fg="red")
        label.place(x=1105,y=72)
    elif dna==0:
        label=Label(enroll_course_screen,text="*Please fill correct district.",font=("Calibri",10),fg="red")
        label.place(x=685,y=146)
    # check mobile number correct or not
    elif d==0:
        label=Label(enroll_course_screen,text="*Please fill correct phone number.",font=("Calibri",10),fg="red")
        label.place(x=685,y=216)
    
    # check age is correct or not
    elif ae==0:
        label=Label(enroll_course_screen,text="*Please fill correct age lies between 18 to 23.",font=("Calibri",10),fg="red")
        label.place(x=395,y=275)
    elif be==0:
        label=Label(enroll_course_screen,text="*Please fill correct date format.",font=("Calibri",10),fg="red")
        label.place(x=395,y=275)
    elif cn==0:
        label=Label(enroll_course_screen,text="*Please fill correct Course Name.",font=("Calibri",10),fg="red")
        label.place(x=415,y=330)
    elif ci==0:
        label=Label(enroll_course_screen,text="*Please fill correct Course ID.",font=("Calibri",10),fg="red")
        label.place(x=415,y=391)
    elif ed==0:
        label=Label(enroll_course_screen,text="*Please fill correct Email.",font=("Calibri",10),fg="red")
        label.place(x=415,y=463)
    
    else:
        conn.execute('''create table if not exists enroll(name varchar(35), father_name varchar(35), 
                    mother_name varchar(35), gender varchar(6),date_birth varchar, age int, 
                   course varchar(10), course_id int, state varchar,
                    nationality varchar(10), district varchar(25), email varchar(40) primary key,
                     address varchar(110), mobile_no int,username varchar(40) )''')
    
        conn.execute('''insert into enroll values(:name,:father_name,:mother_name,:gender,:date_birth,:age,
                     :course,:course_id,:state,:nationality,:district,:email,:address,:mobile_no,:username)''',
                     {
                       'name':name_entry.get(),
                       'father_name':father_name_entry.get(),
                       'mother_name':mother_name_entry.get(),
                       'gender':gender.get(),
                       'date_birth':ent.get(), 
                       'age':int(age_entry.get()),
                       'course':course_name_entry.get(),
                       'course_id':int(course_id_entry.get()),
                       'state':state.get(),
                       'nationality':nation.get(),
                       'district':district_entry.get(),
                       'email':email_entry.get(),
                       'address':address_entry.get(),
                       'mobile_no':int(mob_entry.get()),
                       'username': login_user_name_entry.get()
                     }
                    )
        conn.commit()
        tkinter.messagebox.showinfo("Successfull","Form is successfully Submitted")
        
    
    
    
    
    
    
def back(top):
    top.destroy()
    
def admin():
    return
    
    
    
def exit():
    root.destroy()
    
main_screen()
# Out:
# Already submitted!
